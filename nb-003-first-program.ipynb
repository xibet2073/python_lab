# %% [markdown]
# ## Sum

# %%
1 + 1
# Out:
# 2

# %% [markdown]
# ## print() function

# %%
print("Hello Python")

# %% [markdown]
# ## Syntax error

# %%
print("Hello Python)

# %% [markdown]
# ## Run-time error

# %%
print(Hello, Python)

# %% [markdown]
# ## Assignement operator

# %%
phrase = "Hello world"
print(phrase)

# %% [markdown]
# ## Variables are case-sensitive

# %% [markdown]
# phrase = "Hello Python"

# %%
phrase = "Hello Python"
print(Phrase)

# %% [markdown]
# ## Inspecting variables

# %%
phrase = "Hello, world"
phrase

# %%
x = 2
x

# %%
y = "2"
y

# %%
"""
x = 10
y = 20
"""
